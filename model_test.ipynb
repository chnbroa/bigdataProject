# %%
from tensorflow.keras.models import load_model
import numpy as np
import os
import cv2

image_size = (224, 224)
model = load_model('model.h5')
# model.summary()
name = {
    0: '검은별무늬병',
    1: '그을음병',
    2: '노균병',
    3: '덩굴마름병',
    4: '모자이크병',
    5: '세균성모무늬병',
    6: '정상',
    7: '탄저병',
    8: '흰가루병',
}


base_dir = "C:/test/"
img_list = os.listdir(base_dir)
for test_img in img_list:
    test_x = []
    img_path = base_dir + test_img
    img = cv2.imdecode(np.fromfile(
        img_path, dtype=np.uint8), cv2.IMREAD_UNCHANGED)
    img = cv2.resize(img, image_size)
    test_x.append(img / 256)
    a = np.array(test_x)
    modelpredict = model.predict(a).reshape(-1)
    print(img_path)
    index = np.argmax(modelpredict)
    print(f"인덱스  {index}")
    result = "병명: "+name[index] + \
        ", 정확도:{:.3f}%".format(modelpredict[index] * 100)
    print(result)


# 예측결과 처참...
# 검은별무늬병 다시
# 그을음병은다시 ( 제외  고려)
# 노균병 다시
# Out:
# C:/test/f1_80(1).jpg
# 인덱스  2
# 병명: 노균병, 정확도:97.808%
# C:/test/f1_80(2).jpg
# 인덱스  2
# 병명: 노균병, 정확도:98.667%
# C:/test/f1_80(3).jpg
# 인덱스  6
# 병명: 정상, 정확도:70.706%
# C:/test/f1_80(4).jpg
# 인덱스  6
# 병명: 정상, 정확도:77.156%
# C:/test/f1_80(6).jpg
# 인덱스  0
# 병명: 검은별무늬병, 정확도:96.293%
# C:/test/f1_80(7).jpg
# 인덱스  2
# 병명: 노균병, 정확도:91.514%
# C:/test/f1_80(8).jpg
# 인덱스  6
# 병명: 정상, 정확도:50.481%
# C:/test/f1_80(9).jpg
# 인덱스  8
# 병명: 흰가루병, 정확도:58.255%
# C:/test/inverted_13.png
# 인덱스  2
# 병명: 노균병, 정확도:64.625%
# C:/test/inverted_14.png
# 인덱스  2
# 병명: 노균병, 정확도:64.625%
# C:/test/inverted_15.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/inverted_16.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.983%
# C:/test/inverted_17.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:95.606%
# C:/test/inverted_2.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/inverted_23.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:95.606%
# C:/test/inverted_24.png
# 인덱스  2
# 병명: 노균병, 정확도:62.054%
# C:/test/inverted_29.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:95.606%
# C:/test/inverted_3.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/inverted_34.png
# 인덱스  4
# 병명: 모자이크병, 정확도:76.000%
# C:/test/inverted_38.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.981%
# C:/test/inverted_4.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:76.411%
# C:/test/inverted_40.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/inverted_42.png
# 인덱스  2
# 병명: 노균병, 정확도:64.625%
# C:/test/inverted_46.png
# 인덱스  2
# 병명: 노균병, 정확도:74.075%
# C:/test/inverted_48.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.983%
# C:/test/inverted_49.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/inverted_50.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.996%
# C:/test/inverted_51.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/inverted_52.png
# 인덱스  2
# 병명: 노균병, 정확도:62.054%
# C:/test/inverted_56.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:95.606%
# C:/test/inverted_57.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:95.606%
# C:/test/inverted_59.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:45.470%
# C:/test/inverted_63.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:95.606%
# C:/test/inverted_66.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:95.606%
# C:/test/inverted_7.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/inverted_70.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.996%
# C:/test/inverted_71.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.985%
# C:/test/inverted_72.png
# 인덱스  4
# 병명: 모자이크병, 정확도:76.000%
# C:/test/inverted_73.png
# 인덱스  2
# 병명: 노균병, 정확도:74.075%
# C:/test/inverted_76.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/inverted_77.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/inverted_78.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/inverted_9.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/j1_145(1).jpg
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.974%
# C:/test/j1_145(2).jpg
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/j1_145(3).jpg
# 인덱스  0
# 병명: 검은별무늬병, 정확도:98.437%
# C:/test/j1_145(4).jpg
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/j1_145(5).jpg
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.784%
# C:/test/j1_145(6).jpg
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.997%
# C:/test/j1_145(7).jpg
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.198%
# C:/test/j1_145(8).jpg
# 인덱스  2
# 병명: 노균병, 정확도:45.428%
# C:/test/j1_145(9).jpg
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.994%
# C:/test/noiseAdded_12.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:95.949%
# C:/test/noiseAdded_18.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:95.471%
# C:/test/noiseAdded_19.png
# 인덱스  3
# 병명: 덩굴마름병, 정확도:72.901%
# C:/test/noiseAdded_21.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:95.783%
# C:/test/noiseAdded_22.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:97.663%
# C:/test/noiseAdded_27.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.756%
# C:/test/noiseAdded_30.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.994%
# C:/test/noiseAdded_35.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:97.299%
# C:/test/noiseAdded_37.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.738%
# C:/test/noiseAdded_45.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/noiseAdded_47.png
# 인덱스  3
# 병명: 덩굴마름병, 정확도:73.677%
# C:/test/noiseAdded_5.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:95.785%
# C:/test/noiseAdded_53.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:98.854%
# C:/test/noiseAdded_58.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/noiseAdded_62.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:96.703%
# C:/test/noiseAdded_64.png
# 인덱스  8
# 병명: 흰가루병, 정확도:99.984%
# C:/test/noiseAdded_65.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/noiseAdded_69.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.731%
# C:/test/noiseAdded_74.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:96.848%
# C:/test/noiseAdded_8.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.842%
# C:/test/rotated_1.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.502%
# C:/test/rotated_10.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.990%
# C:/test/rotated_11.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.987%
# C:/test/rotated_20.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/rotated_25.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/rotated_26.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.995%
# C:/test/rotated_28.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/rotated_31.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.999%
# C:/test/rotated_32.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.912%
# C:/test/rotated_33.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.912%
# C:/test/rotated_36.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.660%
# C:/test/rotated_39.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:82.869%
# C:/test/rotated_41.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.886%
# C:/test/rotated_43.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/rotated_44.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/rotated_54.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.842%
# C:/test/rotated_55.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/rotated_6.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/rotated_60.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.681%
# C:/test/rotated_61.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/rotated_67.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:100.000%
# C:/test/rotated_68.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.998%
# C:/test/rotated_75.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:99.896%
# C:/test/rotated_79.png
# 인덱스  0
# 병명: 검은별무늬병, 정확도:93.415%
