# %%
import random
import numpy as np
import os
import cv2
import glob
from PIL import Image
import PIL.ImageOps    

#다음 변수를 수정하여 새로 만들 이미지 갯수를 정합니다.
num_augmented_images = 80

data_name = ["검은별무늬병", "그을음병", "노균병","덩굴마름병","모자이크병","세균성모무늬병","탄저병","흰가루병","정상"]
file_path = f'C:/data/{data_name[3]}/'
save_file_path = f'C:/data/{data_name[3]}증폭/'

if not os.path.isdir(save_file_path): #폴더가 존재하지 않는다면 폴더 생성추가
    os.makedirs(save_file_path)

file_names = os.listdir(file_path)
total_origin_image_num = len(file_names)
augment_cnt = 1

for i in range(1, num_augmented_images):
    change_picture_index = random.randrange(1, total_origin_image_num-1)
    print(change_picture_index)
    print(file_names[change_picture_index])
    file_name = file_names[change_picture_index]
    origin_image_path = file_path + file_name
    print(origin_image_path)
    image = Image.open(origin_image_path)
    random_augment = random.randrange(1,2)
    
    if(random_augment == 1):
        #이미지 좌우 반전
        print("invert")
        inverted_image = image.transpose(Image.FLIP_LEFT_RIGHT)
        inverted_image.save(save_file_path + 'inverted_' + str(augment_cnt) + '.png')
        
    elif(random_augment == 2):
        #이미지 기울이기
        print("rotate")
        rotated_image = image.rotate(random.randrange(-20, 20))
        rotated_image.save(save_file_path + 'rotated_' + str(augment_cnt) + '.png')

    augment_cnt += 1
    
    
#출처 https://github.com/BUZZINGPolarBear/Why_Am_I_ALONE/blob/master/Image_Augmentation.ipynb
# Out:
# 5
# a1_101(6).jpg
# C:/data/덩굴마름병/a1_101(6).jpg
# invert
# 110
# rotated_49.png
# C:/data/덩굴마름병/rotated_49.png
# invert
# 105
# rotated_37.png
# C:/data/덩굴마름병/rotated_37.png
# invert
# 9
# a1_9(1).jpg
# C:/data/덩굴마름병/a1_9(1).jpg
# invert
# 109
# rotated_47.png
# C:/data/덩굴마름병/rotated_47.png
# invert
# 9
# a1_9(1).jpg
# C:/data/덩굴마름병/a1_9(1).jpg
# invert
# 83
# noiseAdded_56.png
# C:/data/덩굴마름병/noiseAdded_56.png
# invert
# 63
# j1_167(9).jpg
# C:/data/덩굴마름병/j1_167(9).jpg
# invert
# 121
# rotated_75.png
# C:/data/덩굴마름병/rotated_75.png
# invert
# 26
# c1_30(7).jpg
# C:/data/덩굴마름병/c1_30(7).jpg
# invert
# 80
# noiseAdded_50.png
# C:/data/덩굴마름병/noiseAdded_50.png
# invert
# 67
# noiseAdded_21.png
# C:/data/덩굴마름병/noiseAdded_21.png
# invert
# 51
# j1_144(6).jpg
# C:/data/덩굴마름병/j1_144(6).jpg
# invert
# 95
# rotated_18.png
# C:/data/덩굴마름병/rotated_18.png
# invert
# 115
# rotated_6.png
# C:/data/덩굴마름병/rotated_6.png
# invert
# 12
# a1_98(2).jpg
# C:/data/덩굴마름병/a1_98(2).jpg
# invert
# 74
# noiseAdded_35.png
# C:/data/덩굴마름병/noiseAdded_35.png
# invert
# 54
# j1_144(9).jpg
# C:/data/덩굴마름병/j1_144(9).jpg
# invert
# 31
# inverted_13.png
# C:/data/덩굴마름병/inverted_13.png
# invert
# 84
# noiseAdded_57.png
# C:/data/덩굴마름병/noiseAdded_57.png
# invert
# 30
# inverted_12.png
# C:/data/덩굴마름병/inverted_12.png
# invert
# 25
# c1_30(6).jpg
# C:/data/덩굴마름병/c1_30(6).jpg
# invert
# 20
# c1_30(1).jpg
# C:/data/덩굴마름병/c1_30(1).jpg
# invert
# 5
# a1_101(6).jpg
# C:/data/덩굴마름병/a1_101(6).jpg
# invert
# 55
# j1_167(1).jpg
# C:/data/덩굴마름병/j1_167(1).jpg
# invert
# 5
# a1_101(6).jpg
# C:/data/덩굴마름병/a1_101(6).jpg
# invert
# 66
# noiseAdded_15.png
# C:/data/덩굴마름병/noiseAdded_15.png
# invert
# 34
# inverted_2.png
# C:/data/덩굴마름병/inverted_2.png
# invert
# 47
# j1_144(2).jpg
# C:/data/덩굴마름병/j1_144(2).jpg
# invert
# 77
# noiseAdded_42.png
# C:/data/덩굴마름병/noiseAdded_42.png
# invert
# 123
# rotated_77.png
# C:/data/덩굴마름병/rotated_77.png
# invert
# 9
# a1_9(1).jpg
# C:/data/덩굴마름병/a1_9(1).jpg
# invert
# 70
# noiseAdded_28.png
# C:/data/덩굴마름병/noiseAdded_28.png
# invert
# 72
# noiseAdded_30.png
# C:/data/덩굴마름병/noiseAdded_30.png
# invert
# 38
# inverted_45.png
# C:/data/덩굴마름병/inverted_45.png
# invert
# 19
# a1_98(9).jpg
# C:/data/덩굴마름병/a1_98(9).jpg
# invert
# 103
# rotated_32.png
# C:/data/덩굴마름병/rotated_32.png
# invert
# 82
# noiseAdded_54.png
# C:/data/덩굴마름병/noiseAdded_54.png
# invert
# 7
# a1_101(8).jpg
# C:/data/덩굴마름병/a1_101(8).jpg
# invert
# 115
# rotated_6.png
# C:/data/덩굴마름병/rotated_6.png
# invert
# 3
# a1_101(4).jpg
# C:/data/덩굴마름병/a1_101(4).jpg
# invert
# 49
# j1_144(4).jpg
# C:/data/덩굴마름병/j1_144(4).jpg
# invert
# 26
# c1_30(7).jpg
# C:/data/덩굴마름병/c1_30(7).jpg
# invert
# 121
# rotated_75.png
# C:/data/덩굴마름병/rotated_75.png
# invert
# 68
# noiseAdded_22.png
# C:/data/덩굴마름병/noiseAdded_22.png
# invert
# 124
# rotated_79.png
# C:/data/덩굴마름병/rotated_79.png
# invert
# 39
# inverted_48.png
# C:/data/덩굴마름병/inverted_48.png
# invert
# 85
# noiseAdded_58.png
# C:/data/덩굴마름병/noiseAdded_58.png
# invert
# 103
# rotated_32.png
# C:/data/덩굴마름병/rotated_32.png
# invert
# 27
# c1_30(8).jpg
# C:/data/덩굴마름병/c1_30(8).jpg
# invert
# 28
# c1_30(9).jpg
# C:/data/덩굴마름병/c1_30(9).jpg
# invert
# 52
# j1_144(7).jpg
# C:/data/덩굴마름병/j1_144(7).jpg
# invert
# 68
# noiseAdded_22.png
# C:/data/덩굴마름병/noiseAdded_22.png
# invert
# 10
# a1_9(2).jpg
# C:/data/덩굴마름병/a1_9(2).jpg
# invert
# 75
# noiseAdded_36.png
# C:/data/덩굴마름병/noiseAdded_36.png
# invert
# 114
# rotated_59.png
# C:/data/덩굴마름병/rotated_59.png
# invert
# 99
# rotated_26.png
# C:/data/덩굴마름병/rotated_26.png
# invert
# 8
# a1_101(9).jpg
# C:/data/덩굴마름병/a1_101(9).jpg
# invert
# 107
# rotated_43.png
# C:/data/덩굴마름병/rotated_43.png
# invert
# 16
# a1_98(6).jpg
# C:/data/덩굴마름병/a1_98(6).jpg
# invert
# 107
# rotated_43.png
# C:/data/덩굴마름병/rotated_43.png
# invert
# 87
# noiseAdded_65.png
# C:/data/덩굴마름병/noiseAdded_65.png
# invert
# 7
# a1_101(8).jpg
# C:/data/덩굴마름병/a1_101(8).jpg
# invert
# 35
# inverted_38.png
# C:/data/덩굴마름병/inverted_38.png
# invert
# 13
# a1_98(3).jpg
# C:/data/덩굴마름병/a1_98(3).jpg
# invert
# 71
# noiseAdded_3.png
# C:/data/덩굴마름병/noiseAdded_3.png
# invert
# 68
# noiseAdded_22.png
# C:/data/덩굴마름병/noiseAdded_22.png
# invert
# 114
# rotated_59.png
# C:/data/덩굴마름병/rotated_59.png
# invert
# 68
# noiseAdded_22.png
# C:/data/덩굴마름병/noiseAdded_22.png
# invert
# 56
# j1_167(2).jpg
# C:/data/덩굴마름병/j1_167(2).jpg
# invert
# 88
# noiseAdded_66.png
# C:/data/덩굴마름병/noiseAdded_66.png
# invert
# 110
# rotated_49.png
# C:/data/덩굴마름병/rotated_49.png
# invert
# 27
# c1_30(8).jpg
# C:/data/덩굴마름병/c1_30(8).jpg
# invert
# 25
# c1_30(6).jpg
# C:/data/덩굴마름병/c1_30(6).jpg
# invert
# 60
# j1_167(6).jpg
# C:/data/덩굴마름병/j1_167(6).jpg
# invert
# 93
# rotated_14.png
# C:/data/덩굴마름병/rotated_14.png
# invert
# 117
# rotated_69.png
# C:/data/덩굴마름병/rotated_69.png
# invert
# 22
# c1_30(3).jpg
# C:/data/덩굴마름병/c1_30(3).jpg
# invert
# 1
# a1_101(2).jpg
# C:/data/덩굴마름병/a1_101(2).jpg
# invert
